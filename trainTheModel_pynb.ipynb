# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-3c9a0bf2-f9dc-d568-cfa8-93aa8d01b9e0)

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 902.2/902.2 kB 17.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !yolo task=detect mode=train model=yolov8n.pt data= ../content/drive/MyDrive/dataset/data.yaml epochs=20 imgsz=640 batch=8  lr0=0.001 resume=False
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 78.2MB/s]
# Ultralytics 8.3.52 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data= ../content/drive/MyDrive/dataset/data.yaml epochs=30 imgsz=640 batch=8
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 283MB/s]
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
import shutil

# Zip the "runs" folder
shutil.make_archive('/content/runs_folder', 'zip', '/content/runs')

# Now, create a download link
from google.colab import files
files.download('/content/runs_folder.zip')
